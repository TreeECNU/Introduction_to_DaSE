# %% [markdown]
# ![homework7.png](attachment:homework7.png)

# %% [markdown]
# CREATE TABLE 'user' (
#     'id' int(11) NOT NULL AUTO_INCREMENT,
#     'name' varchar(30) NOT NULL,
#     'sex' int(11) DEFAULT NULL,
#     'age' int(11) DEFAULT NULL,
#     'phone' varchar(30) DEFAULT NULL,
#     PRIMARY KEY ('id')
# );
# INSERT INTO 'user' VALUES (1, '李华', 1, 29, '13344556677');
# INSERT INTO 'user' VALUES (2, '张华', 0, 31, '13344556678');
# INSERT INTO 'user' VALUES (3, '韩华', 1, 22, '13344556679');
# INSERT INTO 'user' VALUES (4, '谢华', 0, 40, '13344556680');
# INSERT INTO 'user' VALUES (5, '大华', 1, 38, '13344556681');
# INSERT INTO 'user' VALUES (6, '小华', 0, 21, '13344556682');

# %% [markdown]
# SELECT * FROM user WHERE age BETWEEN 20 AND 30;

# %% [markdown]
# DELETE FROM user WHERE name LIKE "%张%";

# %% [markdown]
# SELECT AVG(age) FROM user;

# %% [markdown]
# SELECT * FROM user WHERE age BETWEEN 20 AND 30 AND name LIKE "%张%" ORDER BY age DESC;

# %% [markdown]
# CREATE TABLE 'team' (
#     'id' int(11) NOT NULL AUTO_INCREMENT,
#     'teamName' varchar(30) NOT NULL,
#     PRIMARY KEY ('id')
# );
# INSERT INTO 'team' VALUES (1, 'ECNU');
# INSERT INTO 'team' VALUES (2, 'ECNU');
# INSERT INTO 'team' VALUES (3, 'ECNU');
# INSERT INTO 'team' VALUES (4, 'FDU');
# INSERT INTO 'team' VALUES (5, 'SJTU');
# INSERT INTO 'team' VALUES (6, 'TJU');

# %% [markdown]
# CREATE TABLE 'score' (
#     'id' int(11) NOT NULL AUTO_INCREMENT,
#     'teamid' int(11) NOT NULL AUTO_INCREMENT,
#     'userid' int(11) NOT NULL AUTO_INCREMENT,
#     'score' int(11) NOT NULL AUTO_INCREMENT,
#     PRIMARY KEY ('id'),
#     FOREIGN KEY (teamid) REFERENCES team(id),
#     FOREIGN KEY (userid) REFERENCES user(id)
# );
# INSERT INTO 'score' VALUES (1, 1, 1, 10);
# INSERT INTO 'score' VALUES (2, 2, 2, 9);
# INSERT INTO 'score' VALUES (3, 3, 3, 8);
# INSERT INTO 'score' VALUES (4, 4, 4, 7);
# INSERT INTO 'score' VALUES (5, 5, 5, 6);
# INSERT INTO 'score' VALUES (6, 6, 6, 5);

# %% [markdown]
# SELECT user.id, user.name, user.sex, user.age, user.phone
# FROM team WHERE teamName = 'ECNU'

# %% [markdown]
# SELECT SUM(score.score) FROM team WHERE teamName = 'ECNU'
